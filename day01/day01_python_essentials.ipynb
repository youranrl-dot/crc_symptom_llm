# %% [markdown]
# # Python Essentials
#
# In the previous notebook we learned about Jupyter and some basic Python data types. Before we dive into data analysis with pandas, let's fill in a few essential Python skills that will come up constantly:
#
# 1. **Booleans & Conditionals** — making decisions in code
# 2. **Imports** — using code other people wrote
# 3. **String methods & f-strings** — manipulating text
# 4. **List & dictionary operations** — working with collections
# 5. **Defining functions** — packaging up reusable logic
#
# As before, run each code cell with **Shift + Enter**.

# %% [markdown]
# ---
# ## 1. Booleans & Conditionals
#
# A **boolean** is a value that is either `True` or `False`. Booleans are the foundation of decision-making in code.

# %%
is_sunny = True
is_raining = False

print(is_sunny)
print(type(is_sunny))

# %% [markdown]
# ### Comparison operators
#
# You create booleans by **comparing** values. Here are the comparison operators:
#
# | Operator | Meaning |
# |---|---|
# | `==` | equal to |
# | `!=` | not equal to |
# | `<` | less than |
# | `>` | greater than |
# | `<=` | less than or equal to |
# | `>=` | greater than or equal to |
#
# **Important:** `=` *assigns* a value. `==` *compares* two values.

# %%
temperature = 72

print(temperature > 80)
print(temperature == 72)
print(temperature != 72)
print(temperature <= 100)

# %% [markdown]
# ### `if`, `elif`, `else`
#
# Booleans let us write code that makes **decisions**. The pattern is:
#
# ```python
# if condition:
#     # do this
# elif other_condition:
#     # do this instead
# else:
#     # do this if nothing above was True
# ```
#
# Python uses **indentation** (4 spaces) to know which code belongs inside each block.

# %%
temperature = 85

if temperature > 90:
    print("It's really hot!")
elif temperature > 70:
    print("It's a nice day.")
else:
    print("You might want a jacket.")
# Out:
# It's a nice day.

# %% [markdown]
# Try changing the value of `temperature` above and re-running the cell. Which branch runs?
#
# Remember from the previous notebook: when you change a variable and re-run its cell, the new value is now in Python's memory. But any cell that *already used* the old value won't update automatically — you need to re-run those cells too.

# %% [markdown]
# ### Combining conditions with `and`, `or`, `not`
#
# You can combine multiple conditions:
#
# - `and` — both must be True
# - `or` — at least one must be True
# - `not` — flips True to False (and vice versa)

# %%
temperature = 75
is_sunny = True

if temperature > 60 and is_sunny:
    print("Great day for a walk!")

if temperature > 100 or is_sunny:
    print("You'll want sunscreen.")

if not is_raining:
    print("No umbrella needed.")
# Out:
# Great day for a walk!
# You'll want sunscreen.
# No umbrella needed.

# %% [markdown]
# **Why this matters for data science:** When we get to pandas, we'll filter data with conditions like `df[df["age"] > 30]`. The `>` produces a column of booleans, and pandas keeps only the `True` rows. Same idea, bigger scale!

# %% [markdown]
# ### Exercise 1: Conditionals
#
# Write code that takes a variable `score` (a number from 0–100) and prints the letter grade:
# - 90 and above: `"A"`
# - 80–89: `"B"`
# - 70–79: `"C"`
# - Below 70: `"Needs improvement"`
#
# Test it with a few different values of `score`.

# %%
score = 85

# Your code here

# %% [markdown]
# ---
# ## 2. Imports
#
# Python comes with a lot of built-in functions (`print`, `len`, `sum`, etc.), but most of its power comes from **libraries** — collections of code that other people have written.
#
# To use a library, you **import** it.

# %%
import math

print(math.sqrt(144))
print(math.pi)
# Out:
# 12.0
# 3.141592653589793

# %% [markdown]
# `math` is a library that comes with Python. After importing it, we access its functions and values with a dot: `math.sqrt()`, `math.pi`.

# %% [markdown]
# ### Aliasing with `as`
#
# Some library names are long, so we give them a shorter **alias**. This is just a nickname.

# %%
import math as m

# Now we can use m instead of math
print(m.sqrt(144))
# Out:
# 12.0

# %% [markdown]
# You'll see this pattern constantly in data science:
#
# ```python
# import pandas as pd        # pd is the standard alias for pandas
# import matplotlib.pyplot as plt  # plt is the standard alias for matplotlib
# import numpy as np         # np is the standard alias for numpy
# ```
#
# These aliases are conventions — everyone uses them, so you'll recognize them in tutorials and documentation.

# %% [markdown]
# ### Importing specific things with `from`
#
# If you only need one or two things from a library, you can import them directly.

# %%
from math import sqrt, pi

# Now we can use sqrt and pi directly, without the math. prefix
print(sqrt(144))
print(pi)
# Out:
# 12.0
# 3.141592653589793

# %% [markdown]
# > **Common beginner mistake:** using a library before running the `import` cell. If you see a `NameError` for something like `pd`, `plt`, or `np` later in this course, scroll up and make sure you ran the import cell first. Imports are just regular code cells — they have to be **executed** before anything that uses them.

# %% [markdown]
# ### Built-in vs. external libraries
#
# - **Built-in** libraries (like `math`, `string`, `random`) come with Python — just `import` them.
# - **External** libraries (like `pandas`, `matplotlib`) need to be **installed** first, usually with `pip install pandas` in your terminal. In this workshop, they're already installed for you!

# %% [markdown]
# ### Exercise 2: Imports
#
# Import the `random` library and use `random.randint(1, 10)` to generate a random number between 1 and 10. Print it. Run the cell a few times — do you get different numbers?

# %%
import random

random_number = random.randint(1, 10)
print(f"Random number: {random_number}")
# Out:
# Random number: 1

# %% [markdown]
# ---
# ## 3. String Methods & f-strings
#
# In the previous notebook we saw that strings are sequences of characters. Python gives us many built-in **methods** for working with strings.
#
# A **method** is a function that belongs to an object — you call it with a dot: `my_string.upper()`.

# %%
message = "  Hello, World!  "

print(message.upper())
print(message.lower())
print(message.strip())       # Remove leading/trailing whitespace
print(message.replace("World", "Python"))
# Out:
#   HELLO, WORLD!
#   hello, world!
# Hello, World!
#   Hello, Python!

# %%
# .split() breaks a string into a list of words
sentence = "data science is awesome"
words = sentence.split()
print(words)
print(len(words))
# Out:
# ['data', 'science', 'is', 'awesome']
# 4

# %% [markdown]
# ### f-strings: formatted string literals
#
# An **f-string** lets you embed variables directly inside a string. Just put `f` before the opening quote and use `{}` around your variables.

# %%
name = "Ada"
age = 28
city = "Ann Arbor"

# Without f-strings (clunky)
print("My name is " + name + " and I am " + str(age) + " years old.")

# With f-strings (much cleaner!)
print(f"My name is {name} and I am {age} years old.")
print(f"{name} lives in {city}.")
# Out:
# My name is Ada and I am 28 years old.
# My name is Ada and I am 28 years old.
# Ada lives in Ann Arbor.

# %% [markdown]
# You can put any expression inside the `{}`:

# %%
price = 19.99
quantity = 3

print(f"Total: ${price * quantity:.2f}")  # .2f means 2 decimal places
# Out:
# Total: $59.97

# %% [markdown]
# ### Type conversion
#
# Sometimes you need to convert between types. Python gives you `str()`, `int()`, and `float()` for this.

# %% [markdown]
# **🤔 Guess first:** `x = "42"` — with quotes. Before running the next cell, predict what `type(x)` prints, and what happens after `int(x)`. Bonus prediction: what do you think `int("hello")` would do?

# %%
x = "42"
print(type(x))        # It's a string!

x_as_int = int(x)
print(type(x_as_int)) # Now it's an integer
print(x_as_int + 8)   # And we can do math with it
# Out:
# <class 'str'>
# <class 'int'>
# 50

# %% [markdown]
# ### Exercise 3: Strings
#
# Create variables for your name and your favorite food. Use an f-string to print: `"Hi, my name is [NAME] and I love [FOOD]!"` — but make the food ALL CAPS using `.upper()`.

# %%
my_name = "Your Name"
my_favorite_food = "pizza"

print(f"Hi, my name is {my_name} and I love {my_favorite_food.upper()}!")
# Out:
# Hi, my name is Your Name and I love PIZZA!

# %% [markdown]
# ---
# ## 4. List & Dictionary Operations
#
# In the previous notebook we created lists and dictionaries. Now let's learn how to **modify** and **search** them.

# %% [markdown]
# ### Building up a list
#
# Use `.append()` to add one item at a time.

# %%
fruits = ["apple", "banana"]
print(f"Before: {fruits}")

fruits.append("cherry")
fruits.append("date")
print(f"After: {fruits}")
# Out:
# Before: ['apple', 'banana']
# After: ['apple', 'banana', 'cherry', 'date']

# %% [markdown]
# ### Slicing lists
#
# You can grab a **slice** (a sub-section) of a list using `[start:stop]`. The `start` index is included, but `stop` is **not** included.

# %% [markdown]
# **🤔 Guess first:** `numbers` is `[10, 20, 30, 40, 50, 60]`. Before running the next cell, predict what `numbers[1:4]` gives you: how many items, and is the item at index `4` included? Then check the other slices against your intuition.

# %%
numbers = [10, 20, 30, 40, 50, 60]

print(numbers[1:4])   # Items at index 1, 2, 3
print(numbers[:3])    # First 3 items (start defaults to 0)
print(numbers[3:])    # Everything from index 3 onward
print(numbers[-1])    # Last item
print(numbers[-2:])   # Last 2 items
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [40, 50, 60]
# 60
# [50, 60]

# %% [markdown]
# ### Checking membership with `in`
#
# Use `in` to check whether something is in a list (or a string, or a dictionary).

# %% [markdown]
# **🤔 Guess first:** Think back to what we appended to `fruits` a few cells ago. Before running the next cell, predict the output of each of the three `print` statements — `True` or `False`?

# %%
print("banana" in fruits)
print("mango" in fruits)

# This is great for conditionals!
if "cherry" in fruits:
    print("We have cherries!")
# Out:
# True
# False
# We have cherries!

# %% [markdown]
# ### List comprehensions (a preview) — *⏱️ if time permits*
#
# A **list comprehension** is a compact way to create a new list by transforming each item in an existing one. You'll see these in data science code, so let's get familiar.

# %%
numbers = [1, 2, 3, 4, 5]

# The long way
squares = []
for n in numbers:
    squares.append(n ** 2)
print(squares)

# The list comprehension way (same result, one line)
squares = [n ** 2 for n in numbers]
print(squares)
# Out:
# [1, 4, 9, 16, 25]
# [1, 4, 9, 16, 25]

# %% [markdown]
# You can even add a condition:

# %% [markdown]
# **🤔 Guess first:** `numbers` is `[1, 2, 3, 4, 5]`. Before running the next cell, write down exactly what list you think `evens` will be.

# %%
# Only keep the even numbers
evens = [n for n in numbers if n % 2 == 0]
print(evens)
# Out:
# [2, 4]

# %% [markdown]
# ### Dictionary operations
#
# Dictionaries store **key-value pairs**. Let's see how to inspect and modify them.

# %%
populations = {"Ann Arbor": 123851, "Detroit": 639111, "Lansing": 112644}

# Look up a value
print(populations["Detroit"])

# Add a new entry
populations["Grand Rapids"] = 198917
print(populations)
# Out:
# 639111
# {'Ann Arbor': 123851, 'Detroit': 639111, 'Lansing': 112644, 'Grand Rapids': 198917}

# %%
# Get all the keys, values, or both
print(list(populations.keys()))
print(list(populations.values()))

# .items() gives you key-value pairs — great for looping
for city, pop in populations.items():
    print(f"{city}: {pop:,} people")  # :, adds commas to numbers
# Out:
# ['Ann Arbor', 'Detroit', 'Lansing', 'Grand Rapids']
# [123851, 639111, 112644, 198917]
# Ann Arbor: 123,851 people
# Detroit: 639,111 people
# Lansing: 112,644 people
# Grand Rapids: 198,917 people

# %%
# Check if a key exists
print("Detroit" in populations)
print("Chicago" in populations)
# Out:
# True
# False

# %% [markdown]
# ### Exercise 4a: Lists
#
# 1. Create a list of 5 cities you'd like to visit.
# 2. Use `.append()` to add a 6th city.
# 3. Print the first 3 cities using slicing.
# 4. Check if `"Tokyo"` is in your list and print the result.

# %%
cities_to_visit = ["Paris", "Rome", "Kyoto", "New York", "Sydney"]
print(f"Initial list: {cities_to_visit}")

cities_to_visit.append("London")
print(f"After appending: {cities_to_visit}")

print(f"First 3 cities: {cities_to_visit[:3]}")

print(f"Is Tokyo in the list? {'Tokyo' in cities_to_visit}")
# Out:
# Initial list: ['Paris', 'Rome', 'Kyoto', 'New York', 'Sydney']
# After appending: ['Paris', 'Rome', 'Kyoto', 'New York', 'Sydney', 'London']
# First 3 cities: ['Paris', 'Rome', 'Kyoto']
# Is Tokyo in the list? False

# %% [markdown]
# ### Exercise 4b: Dictionaries
#
# 1. Create a dictionary mapping 3 countries to their capital cities.
# 2. Add a 4th country.
# 3. Loop through it with `.items()` and print each pair using an f-string: `"The capital of [COUNTRY] is [CAPITAL]."`

# %%
capitals = {
    "France": "Paris",
    "Japan": "Tokyo",
    "Canada": "Ottawa"
}
print(f"Initial dictionary: {capitals}")

capitals["Germany"] = "Berlin"
print(f"After adding Germany: {capitals}")

print("\n--- Capital Cities ---")
for country, capital in capitals.items():
    print(f"The capital of {country} is {capital}.")
# Out:
# Initial dictionary: {'France': 'Paris', 'Japan': 'Tokyo', 'Canada': 'Ottawa'}
# After adding Germany: {'France': 'Paris', 'Japan': 'Tokyo', 'Canada': 'Ottawa', 'Germany': 'Berlin'}
#
# --- Capital Cities ---
# The capital of France is Paris.
# The capital of Japan is Tokyo.
# The capital of Canada is Ottawa.
# The capital of Germany is Berlin.

# %% [markdown]
# ---
# ## 5. Defining Functions
#
# So far we've used built-in functions like `print()`, `len()`, and `sum()`. You can also define your **own** functions to package up a piece of logic and reuse it.
#
# ```python
# def function_name(parameter1, parameter2):
#     # do something
#     return result
# ```
#
# - `def` starts the definition
# - The **parameters** are inputs the function accepts
# - `return` sends a value back to the caller

# %%
def fahrenheit_to_celsius(temp_f):
    """Convert a temperature from Fahrenheit to Celsius."""
    temp_c = (temp_f - 32) * 5/9
    return temp_c

# Now we can use it like any other function
print(fahrenheit_to_celsius(32))
print(fahrenheit_to_celsius(72))
print(fahrenheit_to_celsius(212))
# Out:
# 0.0
# 22.22222222222222
# 100.0

# %% [markdown]
# Once defined, you can call your function as many times as you like. The `"""..."""` on the second line is a **docstring** — a short description of what the function does.
#
# Functions can take multiple parameters:

# %% [markdown]
# **🤔 Guess first:** The function below defines `greeting="Hello"` — a **default value**. Before running the cell, predict: what will `greet("Ada")` print, given that we only passed **one** argument? And `greet("Ada", "Welcome")`?

# %%
def greet(name, greeting="Hello"):
    """Return a greeting for the given name."""
    return f"{greeting}, {name}!"

print(greet("Ada"))
print(greet("Ada", "Welcome"))
# Out:
# Hello, Ada!
# Welcome, Ada!

# %% [markdown]
# ### Exercise 5: Functions
#
# In Exercise 1 you wrote `if`/`elif`/`else` code that turned a `score` into a letter grade. Now make it **reusable**: write a function `get_grade(score)` that **returns** the letter grade as a string (`"A"`, `"B"`, `"C"`, or `"Needs improvement"`).
#
# Then test it by calling it a few times:
#
# ```python
# print(get_grade(95))
# print(get_grade(72))
# print(get_grade(50))
# ```
#
# Notice how much nicer this is than copy-pasting the `if` block every time — that's the whole point of functions!

# %%
def get_grade(score):
    """Returns the letter grade for a given score."""
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    else:
        return "Needs improvement"

# Test the function
print(get_grade(95))
print(get_grade(72))
print(get_grade(50))
# Out:
# A
# C
# Needs improvement

# %% [markdown]
# ---
# ## 🏠 Optional Homework (after hours)
#
# These are **optional** exercises to try tonight. They only use things covered today, but they'll take a bit more thought than the in-class exercises. Bring questions tomorrow!
#
# ### Homework 1: Rectangle printer
#
# Write code that prints a rectangle of `O` characters. The rectangle should always be **5 rows tall**, but its width should come from a variable `width`. For example, with `width = 8`:
#
# ```
# OOOOOOOO
# OOOOOOOO
# OOOOOOOO
# OOOOOOOO
# OOOOOOOO
# ```
#
# *Hint: string replication (`"O" * 8`) and a `for` loop with `range()` will get you there. Bonus: wrap it in a function `print_rectangle(width, height)`.*

# %%
# Homework 1 — your code here

# %% [markdown]
# ### Homework 2: Random weather generator
#
# Write a function `random_weather()` that **returns a dictionary** with these keys:
#
# - `"temp"` — a random integer from `-10` to `100`
# - `"humidity"` — a random integer from `0` to `100`
# - `"is_sunny"` — `True` or `False` (hint: `random.choice([True, False])`)
#
# Then call your function **10 times in a loop**, appending each dictionary to a list called `readings`, and print the list.
#
# *You'll need the `random` library from Exercise 2 — `random.randint(a, b)` gives a random integer between `a` and `b`.*

# %%
# Homework 2 — your code here

# %% [markdown]
# ### Homework 3: Average-temperature analyzer
#
# Building on Homework 2: write a function `average_temp(readings)` that takes your list of weather dictionaries and **returns the average** of all the `"temp"` values.
#
# Print the result with an f-string, rounded to 1 decimal place: `f"Average temperature: {avg:.1f}"`
#
# *Hint: loop through the list, add up each dictionary's `"temp"`, and divide by `len(readings)`. This "loop over a list of dictionaries and summarize a field" pattern is exactly what pandas will automate for us later!*

# %%
# Homework 3 — your code here

# %% [markdown]
# ---
# ## What's next?
#
# You now have the Python fundamentals you need to work with data! In the next notebooks, we'll use **NumPy** to work with arrays of numbers and **pandas** to load, explore, and analyze real datasets — and you'll see all of these concepts (booleans, imports, string methods, list operations, functions) put to work.
#
# ## Key Points
#
# - **Booleans** (`True`/`False`) result from comparisons like `==`, `>`, `<`. Combine them with `and`, `or`, `not`.
# - **`if`/`elif`/`else`** lets your code make decisions based on conditions.
# - **`import`** brings in code from libraries. Use `as` to give a short alias (e.g., `import pandas as pd`).
# - **String methods** like `.upper()`, `.split()`, `.replace()` let you transform text. **f-strings** (`f"...{var}..."`) make formatting easy.
# - **Lists** support `.append()`, slicing (`[1:4]`), and membership testing (`in`).
# - **Dictionaries** let you look up values by key, and `.keys()`, `.values()`, `.items()` help you inspect them.
# - **Define functions** with `def name(params):` and `return`. Use default parameter values to make functions flexible.
